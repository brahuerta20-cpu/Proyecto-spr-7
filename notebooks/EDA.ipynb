# %%
# !pip install pandas matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.4-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----------------- ---------------------- 5.0/11.1 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 29.2 MB/s  0:00:00
# Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------  8.1/8.3 MB 44.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 37.4 MB/s  0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 34.7 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading numpy-2.3.4-cp314-cp314-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------------------------------- -------- 10.2/12.9 MB 48.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 42.8 MB/s  0:00:00
# Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 43.6 MB/s  0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    ----------------------------------------  0/12 [pytz]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    --- ------------------------------------  1/12 [tzdata]
#    ------ ---------------------------------  2/12 [pyparsing]
#    ------ ---------------------------------  2/12 [pyparsing]
#    ------ ---------------------------------  2/12 [pyparsing]
#    ------ ---------------------------------  2/12 [pyparsing]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ---------------- -----------------------  5/12 [kiwisolver]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------- -------------------  6/12 [fonttools]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    -------------------------- -------------  8/12 [pandas]
#    ------------------------------ ---------  9/12 [contourpy]
#    ------------------------------ ---------  9/12 [contourpy]
#    ------------------------------ ---------  9/12 [contourpy]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    --------------------------------- ------ 10/12 [matplotlib]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ------------------------------------ --- 11/12 [seaborn]
#    ---------------------------------------- 12/12 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.3.4 pandas-2.3.3 pillow-12.0.0 pyparsing-3.2.5 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from plotly) (2.11.0)
# Requirement already satisfied: packaging in c:\users\brahu\appdata\roaming\python\python314\site-packages (from plotly) (25.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\brahu\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in c:\users\brahu\appdata\roaming\python\python314\site-packages (9.7.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\brahu\appdata\roaming\python\python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from jedi>=0.18.1->ipython) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\brahu\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\brahu\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "browser"
car_data = pd.read_csv('../vehicles_us.csv') #Leer los datos
fig = px.scatter(car_data, x="odometer", y="price") # crear un histograma
fig.show() # crear gráfico de dispersión
